# %%
pip install crewai duckduckgo-search
# Out:
# Requirement already satisfied: crewai in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (0.102.0)
# Requirement already satisfied: duckduckgo-search in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (7.5.0)
# Requirement already satisfied: click>=8.1.7 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (8.1.8)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (2024.11.6)
# Requirement already satisfied: openai>=1.13.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.64.0)
# Requirement already satisfied: pyvis>=0.3.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (0.3.2)
# Requirement already satisfied: openpyxl>=3.1.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: json-repair>=0.25.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (0.39.1)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.0.1)
# Requirement already satisfied: tomli-w>=1.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.2.0)
# Requirement already satisfied: auth0-python>=4.7.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (4.8.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.30.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (0.11.5)
# Requirement already satisfied: tomli>=2.0.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (2.2.1)
# Requirement already satisfied: litellm==1.60.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.60.2)
# Requirement already satisfied: instructor>=1.3.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.7.2)
# Requirement already satisfied: chromadb>=0.5.23 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (0.6.3)
# Requirement already satisfied: jsonref>=1.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.30.0)
# Requirement already satisfied: pydantic>=2.4.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (2.10.6)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.9.0)
# Requirement already satisfied: uv>=0.4.25 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (0.6.3)
# Requirement already satisfied: json5>=0.10.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (0.10.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai) (1.30.0)
# Requirement already satisfied: aiohttp in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai) (3.11.13)
# Requirement already satisfied: tokenizers in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai) (0.21.0)
# Requirement already satisfied: httpx<0.28.0,>=0.23.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai) (0.27.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai) (0.9.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai) (8.5.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai) (3.1.5)
# Requirement already satisfied: lxml>=5.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from duckduckgo-search) (5.3.1)
# Requirement already satisfied: primp>=0.14.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from duckduckgo-search) (0.14.0)
# Requirement already satisfied: requests>=2.32.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3>=2.2.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.3.0)
# Requirement already satisfied: cryptography>=43.0.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from auth0-python>=4.7.1->crewai) (44.0.1)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (1.18.3)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (5.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (2.4.6)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (1.5.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (25.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (1.3.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (0.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai) (6.1.0)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (0.115.9)
# Requirement already satisfied: typer>=0.9.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (0.15.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (1.20.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (1.30.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (5.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (1.70.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (6.0.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (0.34.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (9.0.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (3.16.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (2.0.2)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (3.10.15)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (4.67.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (4.2.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (0.7.6)
# Requirement already satisfied: importlib-resources in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (4.12.2)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (7.7.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.5.23->crewai) (32.0.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (24.2)
# Requirement already satisfied: pyproject_hooks in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: colorama in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai) (0.45.3)
# Requirement already satisfied: anyio in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (4.8.0)
# Requirement already satisfied: idna in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (3.10)
# Requirement already satisfied: sniffio in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (1.0.7)
# Requirement already satisfied: certifi in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (2025.1.31)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from importlib-metadata>=6.8.0->litellm==1.60.2->crewai) (3.21.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from instructor>=1.3.3->crewai) (2.27.2)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from instructor>=1.3.3->crewai) (0.8.2)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.60.2->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.23.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Requirement already satisfied: requests-oauthlib in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.38.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.5.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9)
# Requirement already satisfied: coloredlogs in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: sympy in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.13.1)
# Requirement already satisfied: protobuf in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (5.29.3)
# Requirement already satisfied: flatbuffers in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (25.2.10)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from anyio->httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (1.2.2)
# Requirement already satisfied: et-xmlfile in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.18)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.17.2)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.30.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.68.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.8.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: Pillow>=9.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pdfplumber>=0.11.4->crewai) (11.1.0)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pdfplumber>=0.11.4->crewai) (20231228)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.4.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: networkx>=1.11 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pyvis>=0.3.2->crewai) (3.4.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pyvis>=0.3.2->crewai) (4.0.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pyvis>=0.3.2->crewai) (8.32.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.50)
# Requirement already satisfied: stack_data in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: decorator in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.2.1)
# Requirement already satisfied: matplotlib-inline in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.19.1)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from tokenizers->litellm==1.60.2->crewai) (0.29.1)
# Requirement already satisfied: filelock in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai) (2025.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.0.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (15.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (3.5.4)
# Requirement already satisfied: pure-eval in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\usman\Desktop\mine\jupyter notebook\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
pip install crewai-tools
# Out:
# Collecting crewai-tools
#   Using cached crewai_tools-0.36.0-py3-none-any.whl (545 kB)
# Requirement already satisfied: requests>=2.31.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai-tools) (2.32.3)
# Requirement already satisfied: chromadb>=0.4.22 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai-tools) (0.6.3)
# Collecting docker>=7.1.0
#   Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Requirement already satisfied: click>=8.1.8 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai-tools) (8.1.8)
# Requirement already satisfied: pydantic>=2.6.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai-tools) (2.10.6)
# Requirement already satisfied: crewai>=0.100.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai-tools) (0.102.0)
# Collecting lancedb>=0.5.4
#   Using cached lancedb-0.20.0-cp39-abi3-win_amd64.whl (30.3 MB)
# Collecting pyright>=1.1.350
#   Using cached pyright-1.1.396-py3-none-any.whl (5.7 MB)
# Requirement already satisfied: openai>=1.12.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai-tools) (1.64.0)
# Collecting pytube>=15.0.0
#   Using cached pytube-15.0.0-py3-none-any.whl (57 kB)
# Collecting embedchain>=0.1.114
#   Using cached embedchain-0.1.127-py3-none-any.whl (211 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (3.10.15)
# Requirement already satisfied: importlib-resources in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (6.5.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.20.1)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (2.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (5.1.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.34.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.48.9)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (4.2.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (9.0.0)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.115.9)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.30.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.27.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.7.6)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (3.16.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (4.12.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.70.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.51b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.30.0)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (4.67.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.2.2.post1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (7.7.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (1.30.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (32.0.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (13.9.4)
# Requirement already satisfied: typer>=0.9.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.15.2)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (6.0.2)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from chromadb>=0.4.22->crewai-tools) (0.20.3)
# Requirement already satisfied: colorama in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from build>=1.0.3->chromadb>=0.4.22->crewai-tools) (0.4.6)
# Requirement already satisfied: pyproject_hooks in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from build>=1.0.3->chromadb>=0.4.22->crewai-tools) (1.2.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from build>=1.0.3->chromadb>=0.4.22->crewai-tools) (24.2)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from build>=1.0.3->chromadb>=0.4.22->crewai-tools) (2.2.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from build>=1.0.3->chromadb>=0.4.22->crewai-tools) (8.5.0)
# Requirement already satisfied: litellm==1.60.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (1.60.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (1.30.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (1.0.1)
# Requirement already satisfied: instructor>=1.3.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (1.7.2)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (2024.11.6)
# Requirement already satisfied: jsonref>=1.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (1.1.0)
# Requirement already satisfied: pyvis>=0.3.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (0.3.2)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (1.9.0)
# Requirement already satisfied: json-repair>=0.25.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (0.39.1)
# Requirement already satisfied: auth0-python>=4.7.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (4.8.1)
# Requirement already satisfied: json5>=0.10.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (0.10.0)
# Requirement already satisfied: openpyxl>=3.1.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (3.1.5)
# Requirement already satisfied: tomli-w>=1.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (1.2.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (1.4.4)
# Requirement already satisfied: uv>=0.4.25 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (0.6.3)
# Requirement already satisfied: pdfplumber>=0.11.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from crewai>=0.100.0->crewai-tools) (0.11.5)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai>=0.100.0->crewai-tools) (0.7.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai>=0.100.0->crewai-tools) (4.23.0)
# Requirement already satisfied: aiohttp in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai>=0.100.0->crewai-tools) (3.11.13)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from litellm==1.60.2->crewai>=0.100.0->crewai-tools) (3.1.5)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from auth0-python>=4.7.1->crewai>=0.100.0->crewai-tools) (2.10.1)
# Requirement already satisfied: cryptography>=43.0.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from auth0-python>=4.7.1->crewai>=0.100.0->crewai-tools) (44.0.1)
# Requirement already satisfied: urllib3>=2.2.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from auth0-python>=4.7.1->crewai>=0.100.0->crewai-tools) (2.3.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (25.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (1.18.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (6.1.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from aiohttp->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (1.3.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai>=0.100.0->crewai-tools) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai>=0.100.0->crewai-tools) (2.22)
# Requirement already satisfied: pywin32>=304 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from docker>=7.1.0->crewai-tools) (308)
# Collecting langchain-openai<0.3.0,>=0.2.1
#   Using cached langchain_openai-0.2.14-py3-none-any.whl (50 kB)
# Collecting pypdf<6.0.0,>=5.0.0
#   Using cached pypdf-5.3.1-py3-none-any.whl (302 kB)
# Collecting mem0ai<0.2.0,>=0.1.54
#   Using cached mem0ai-0.1.62-py3-none-any.whl (99 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.20)
# Collecting pysbd<0.4.0,>=0.3.4
#   Using cached pysbd-0.3.4-py3-none-any.whl (71 kB)
# Collecting schema<0.8.0,>=0.7.5
#   Using cached schema-0.7.7-py2.py3-none-any.whl (18 kB)
# Collecting alembic<2.0.0,>=1.13.1
#   Using cached alembic-1.14.1-py3-none-any.whl (233 kB)
# Collecting langchain-cohere<0.4.0,>=0.3.0
#   Using cached langchain_cohere-0.3.5-py3-none-any.whl (45 kB)
# Collecting gptcache<0.2.0,>=0.1.43
#   Using cached gptcache-0.1.44-py3-none-any.whl (131 kB)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.3.19)
# Collecting chromadb>=0.4.22
#   Using cached chromadb-0.5.23-py3-none-any.whl (628 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (0.1.147)
# Collecting cohere<6.0,>=5.3
#   Using cached cohere-5.14.0-py3-none-any.whl (253 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (4.13.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from embedchain>=0.1.114->crewai-tools) (2.0.38)
# Collecting google-cloud-aiplatform<2.0.0,>=1.26.1
#   Using cached google_cloud_aiplatform-1.82.0-py2.py3-none-any.whl (7.3 MB)
# Collecting Mako
#   Using cached Mako-1.3.9-py3-none-any.whl (78 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain>=0.1.114->crewai-tools) (2.6)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools) (2.27.2)
# Requirement already satisfied: httpx-sse==0.4.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools) (0.4.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools) (1.10.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools) (2.32.0.20250301)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from fastapi>=0.95.2->chromadb>=0.4.22->crewai-tools) (0.45.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.26.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.38.0)
# Collecting shapely<3.0.0dev
#   Using cached shapely-2.0.7-cp310-cp310-win_amd64.whl (1.4 MB)
# Collecting google-cloud-resource-manager<3.0.0dev,>=1.3.3
#   Using cached google_cloud_resource_manager-1.14.1-py2.py3-none-any.whl (392 kB)
# Requirement already satisfied: docstring-parser<1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (0.16)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (5.29.3)
# Collecting google-cloud-storage<3.0.0dev,>=1.32.0
#   Using cached google_cloud_storage-2.19.0-py2.py3-none-any.whl (131 kB)
# Collecting google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0
#   Using cached google_cloud_bigquery-3.30.0-py2.py3-none-any.whl (247 kB)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.24.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.68.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.70.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (0.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (5.5.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.9.0.post0)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.7.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (2.4.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.14.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (0.14.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (1.6.0)
# Requirement already satisfied: certifi in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (2025.1.31)
# Requirement already satisfied: sniffio in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (1.3.1)
# Requirement already satisfied: anyio in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (1.0.7)
# Requirement already satisfied: idna in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb>=0.4.22->crewai-tools) (3.21.0)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from instructor>=1.3.3->crewai>=0.100.0->crewai-tools) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai>=0.100.0->crewai-tools) (0.23.1)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (3.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (1.17.0)
# Requirement already satisfied: requests-oauthlib in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (0.9)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools) (1.8.0)
# Collecting pylance~=0.23.2
#   Using cached pylance-0.23.2-cp39-abi3-win_amd64.whl (34.8 MB)
# Collecting deprecation
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.6)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.3.41)
# Requirement already satisfied: pandas>=1.4.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2.2.3)
# Collecting tabulate<0.10.0,>=0.9.0
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting langchain-experimental<0.4.0,>=0.3.0
#   Using cached langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (2.8.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->embedchain>=0.1.114->crewai-tools) (1.0.0)
# Collecting qdrant-client<2.0.0,>=1.9.1
#   Using cached qdrant_client-1.13.2-py3-none-any.whl (306 kB)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (2024.2)
# Requirement already satisfied: sympy in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools) (1.13.1)
# Requirement already satisfied: coloredlogs in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools) (25.2.10)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from openai>=1.12.0->crewai-tools) (1.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (1.2.2)
# Requirement already satisfied: et-xmlfile in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from openpyxl>=3.1.5->crewai>=0.100.0->crewai-tools) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=0.4.22->crewai-tools) (1.2.18)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb>=0.4.22->crewai-tools) (1.17.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.22->crewai-tools) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.22->crewai-tools) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools) (0.51b0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools) (3.8.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools) (2025.1)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pdfplumber>=0.11.4->crewai>=0.100.0->crewai-tools) (20231228)
# Requirement already satisfied: Pillow>=9.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pdfplumber>=0.11.4->crewai>=0.100.0->crewai-tools) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pdfplumber>=0.11.4->crewai>=0.100.0->crewai-tools) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai>=0.100.0->crewai-tools) (3.4.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai-tools) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai-tools) (2.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pydantic>=2.6.1->crewai-tools) (0.7.0)
# Collecting pyarrow>=14
#   Using cached pyarrow-19.0.1-cp310-cp310-win_amd64.whl (25.3 MB)
# Collecting nodeenv>=1.6.0
#   Using cached nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (4.0.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (8.32.0)
# Requirement already satisfied: networkx>=1.11 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (3.4.2)
# Requirement already satisfied: stack_data in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (0.6.3)
# Requirement already satisfied: decorator in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (5.2.1)
# Requirement already satisfied: matplotlib-inline in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (0.1.7)
# Requirement already satisfied: jedi>=0.16 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (0.19.2)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (5.14.3)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (2.19.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (0.2.13)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (2.10.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (1.70.0)
# Requirement already satisfied: setuptools in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools) (57.4.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from h2<5,>=3->httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from h2<5,>=3->httpx>=0.27.0->chromadb>=0.4.22->crewai-tools) (4.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from rich>=10.11.0->chromadb>=0.4.22->crewai-tools) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.4.22->crewai-tools) (0.1.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools) (3.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from tokenizers>=0.13.2->chromadb>=0.4.22->crewai-tools) (0.29.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.22->crewai-tools) (2025.2.0)
# Requirement already satisfied: filelock in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.22->crewai-tools) (3.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from typer>=0.9.0->chromadb>=0.4.22->crewai-tools) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools) (1.0.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools) (0.6.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools) (15.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools) (1.0.4)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools) (3.5.4)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.100.0->crewai-tools) (2.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools) (1.3.0)
# Installing collected packages: tabulate, shapely, qdrant-client, pyarrow, Mako, langchain-experimental, google-cloud-storage, google-cloud-resource-manager, google-cloud-bigquery, cohere, schema, pysbd, pypdf, pylance, nodeenv, mem0ai, langchain-openai, langchain-cohere, gptcache, google-cloud-aiplatform, deprecation, chromadb, alembic, pytube, pyright, lancedb, embedchain, docker, crewai-tools
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 0.6.3
#     Uninstalling chromadb-0.6.3:
#       Successfully uninstalled chromadb-0.6.3
# Successfully installed Mako-1.3.9 alembic-1.14.1 chromadb-0.5.23 cohere-5.14.0 crewai-tools-0.36.0 deprecation-2.1.0 docker-7.1.0 embedchain-0.1.127 google-cloud-aiplatform-1.82.0 google-cloud-bigquery-3.30.0 google-cloud-resource-manager-1.14.1 google-cloud-storage-2.19.0 gptcache-0.1.44 lancedb-0.20.0 langchain-cohere-0.3.5 langchain-experimental-0.3.4 langchain-openai-0.2.14 mem0ai-0.1.62 nodeenv-1.9.1 pyarrow-19.0.1 pylance-0.23.2 pypdf-5.3.1 pyright-1.1.396 pysbd-0.3.4 pytube-15.0.0 qdrant-client-1.13.2 schema-0.7.7 shapely-2.0.7 tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\usman\Desktop\mine\jupyter notebook\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
pip install transformers -U
# Out:
# Requirement already satisfied: transformers in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (4.49.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: filelock in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (3.17.0)
# Collecting tokenizers<0.22,>=0.21
#   Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl (2.4 MB)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (0.29.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.6.1)
# Requirement already satisfied: colorama in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from requests->transformers) (2.3.0)
# Installing collected packages: tokenizers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\usman\\Desktop\\mine\\jupyter notebook\\myenv\\Lib\\site-packages\\~-kenizers\\tokenizers.cp310-win_amd64.pyd'
# Check the permissions.
#
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\usman\Desktop\mine\jupyter notebook\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
pip install --upgrade numpy transformers torch
# Out:
# Requirement already satisfied: numpy in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (1.26.4)
# Collecting numpy
#   Using cached numpy-2.2.3-cp310-cp310-win_amd64.whl (12.9 MB)
# Requirement already satisfied: transformers in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (4.49.0)
# Requirement already satisfied: torch in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (2.6.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: filelock in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (0.29.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: requests in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: networkx in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from torch) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: fsspec in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usman\desktop\mine\jupyter notebook\myenv\lib\site-packages (from requests->transformers) (3.10)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\usman\\Desktop\\mine\\jupyter notebook\\myenv\\Lib\\site-packages\\~~mpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Check the permissions.
#
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\usman\Desktop\mine\jupyter notebook\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
pip install numpy==1.26.3
# Out:
# Collecting numpy==1.26.3
#   Downloading numpy-1.26.3-cp310-cp310-win_amd64.whl (15.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
# Successfully installed numpy-1.26.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# crewai-tools 0.36.0 requires click>=8.1.8, but you have click 8.1.7 which is incompatible.
# chromadb 0.5.23 requires tokenizers<=0.20.3,>=0.13.2, but you have tokenizers 0.21.0 which is incompatible.
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\usman\Desktop\mine\jupyter notebook\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import os
from crewai import Agent, Task, Crew, Process, LLM
from crewai_tools import tools

# %%
my_llm = LLM(
              model='gemini/gemini-1.5-flash',
              api_key= "google-api-key"
            )

# %%
planner = Agent(
    role="Content Planner",
    goal="Plan engaging and factually accurate content on {topic}",
    backstory="You're working on planning a blog article "
              "about the topic: {topic}."
              "You collect information that helps the "
              "audience learn something "
              "and make informed decisions. "
              "Your work is the basis for "
              "the Content Writer to write an article on this topic.",
    llm=my_llm,
    allow_delegation=False,
	verbose=True
)

# %%
writer = Agent(
    role="Content Writer",
    goal="Write insightful and factually accurate "
         "opinion piece about the topic: {topic}",
    backstory="You're working on a writing "
              "a new opinion piece about the topic: {topic}. "
              "You base your writing on the work of "
              "the Content Planner, who provides an outline "
              "and relevant context about the topic. "
              "You follow the main objectives and "
              "direction of the outline, "
              "as provide by the Content Planner. "
              "You also provide objective and impartial insights "
              "and back them up with information "
              "provide by the Content Planner. "
              "You acknowledge in your opinion piece "
              "when your statements are opinions "
              "as opposed to objective statements.",
    llm=my_llm,
    allow_delegation=False,
    verbose=True
)

# %%
editor = Agent(
    role="Editor",
    goal="Edit a given blog post to align with "
         "the writing style of the organization. ",
    backstory="You are an editor who receives a blog post "
              "from the Content Writer. "
              "Your goal is to review the blog post "
              "to ensure that it follows journalistic best practices,"
              "provides balanced viewpoints "
              "when providing opinions or assertions, "
              "and also avoids major controversial topics "
              "or opinions when possible.",
    llm=my_llm,
    allow_delegation=False,
    verbose=True
)

# %%
plan = Task(
    description=(
        "1. Prioritize the latest trends, key players, "
            "and noteworthy news on {topic}.\n"
        "2. Identify the target audience, considering "
            "their interests and pain points.\n"
        "3. Develop a detailed content outline including "
            "an introduction, key points, and a call to action.\n"
        "4. Include SEO keywords and relevant data or sources."
    ),
    expected_output="A comprehensive content plan document "
        "with an outline, audience analysis, "
        "SEO keywords, and resources.",
    agent=planner,
    llm=my_llm,
)

# %%
write = Task(
    description=(
        "1. Use the content plan to craft a compelling "
            "blog post on {topic}.\n"
        "2. Incorporate SEO keywords naturally.\n"
		"3. Sections/Subtitles are properly named "
            "in an engaging manner.\n"
        "4. Ensure the post is structured with an "
            "engaging introduction, insightful body, "
            "and a summarizing conclusion.\n"
        "5. Proofread for grammatical errors and "
            "alignment with the brand's voice.\n"
    ),
    expected_output="A well-written blog post "
        "in markdown format, ready for publication, "
        "each section should have 2 or 3 paragraphs.",
    agent=writer,
    llm=my_llm,
)

# %%
edit = Task(
    description=("Proofread the given blog post for "
                 "grammatical errors and "
                 "alignment with the brand's voice."),
    expected_output="A well-written blog post in markdown format, "
                    "ready for publication, "
                    "each section should have 2 or 3 paragraphs.",
    agent=editor,
    llm=my_llm,
)

# %%
crew = Crew(
    agents=[planner, writer, editor],
    tasks=[plan, write, edit],
    verbose=True
)
# Out:
# 2025-03-08 21:36:37,124 - 16044 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed

# %%
result = crew.kickoff(inputs={"topic": "Artificial Intelligence"})
# Out:
# # Agent: Content Planner
# ## Task: 1. Prioritize the latest trends, key players, and noteworthy news on Artificial Intelligence.
# 2. Identify the target audience, considering their interests and pain points.
# 3. Develop a detailed content outline including an introduction, key points, and a call to action.
# 4. Include SEO keywords and relevant data or sources.
#
#
# # Agent: Content Planner
# ## Final Answer:
# **Content Plan: Understanding the Rise of Artificial Intelligence**
#
# **1. Prioritized Trends, Key Players, and Noteworthy News:**
#
# * **Trend:** Generative AI –  Focus on advancements in models like GPT-4, DALL-E 2, Stable Diffusion, and their applications in various fields (content creation, art, coding).  This is currently dominating the AI landscape.
# * **Trend:**  AI in Healthcare –  Highlight breakthroughs in drug discovery, personalized medicine, diagnostics, and robotic surgery. Mention companies like IBM Watson Health and Google DeepMind's contributions.
# * **Trend:**  Ethical Considerations and Regulation – Discuss growing concerns about bias in AI, job displacement, and the need for responsible AI development.  Mention the EU's AI Act and other regulatory efforts.
# * **Trend:** AI for Sustainability – Showcase how AI is being used to tackle climate change, optimize energy consumption, and improve resource management.  Examples include AI-powered smart grids and precision agriculture.
# * **Key Players:** OpenAI, Google (DeepMind), Microsoft, Amazon (AWS), Meta, NVIDIA. Briefly describe their key contributions and areas of focus.
# * **Noteworthy News:** Recent significant breakthroughs, funding rounds in AI startups, major partnerships, and any relevant regulatory updates should be included as close to publication as possible.  This will require regular updates to this section.
#
# **2. Target Audience & Pain Points:**
#
# * **Primary Audience:** Professionals (tech leaders, business owners, researchers, students) interested in learning about the latest AI advancements and their potential impact on their respective fields.  Also, individuals curious about the future implications of AI.
# * **Secondary Audience:** General public interested in understanding the basics of AI and its societal impact.
# * **Pain Points:**
#     * Lack of understanding of complex AI concepts.
#     * Difficulty in separating hype from reality regarding AI capabilities.
#     * Concerns about job security and the ethical implications of AI.
#     * Uncertainty about how to leverage AI for personal or professional gain.
#
#
# **3. Detailed Content Outline:**
#
# **I. Introduction (approx. 150 words)**
#
# * Hook: Start with a captivating statistic or a brief anecdote showcasing the impact of AI in everyday life.
# * Briefly define Artificial Intelligence and its core principles.
# * Thesis statement:  This article will explore the latest trends, key players, and ethical considerations surrounding the rapid advancement of AI, empowering readers to understand and navigate this transformative technology.
#
# **II.  Key Trends in Artificial Intelligence (approx. 400 words)**
#
# * **Generative AI:** Explain the capabilities, limitations, and potential applications (examples: marketing copy, image generation, software code).  Include visuals of AI-generated content.
# * **AI in Healthcare:** Detail specific applications and their impact on patient care and medical research.
# * **Ethical Considerations and Regulation:** Discuss bias in algorithms, data privacy concerns, and the need for responsible AI development. Mention relevant regulations and initiatives.
# * **AI for Sustainability:** Highlight successful applications and their contribution to environmental protection.
#
# **III. Key Players Shaping the AI Landscape (approx. 250 words)**
#
# * Briefly profile the leading companies in AI (OpenAI, Google, Microsoft, Amazon, Meta, NVIDIA) focusing on their key contributions and areas of expertise.  Include logos.
#
# **IV.  Navigating the Future of AI (approx. 200 words)**
#
# * Discuss potential future developments and their impact on various sectors.
# * Encourage critical thinking about the potential benefits and risks of AI.
#
# **V. Conclusion (approx. 100 words)**
#
# * Summarize the main points discussed in the article.
# * Reiterate the importance of understanding and engaging responsibly with AI.
#
# **VI. Call to Action:**
#
# * Encourage readers to share their thoughts and engage in further discussion.
# * Suggest additional resources for deeper learning (links to relevant articles, books, or courses).
#
#
# **4. SEO Keywords & Relevant Data/Sources:**
#
# * **Keywords:** Artificial intelligence, AI, generative AI, machine learning, deep learning, AI ethics, AI regulation, AI in healthcare, AI for sustainability, OpenAI, Google DeepMind, Microsoft AI, Amazon AI, Meta AI, NVIDIA, GPT-4, DALL-E 2, Stable Diffusion.
# * **Data Sources:**
#     * Statista: For market size data and adoption rates.
#     * Gartner: For predictions and analysis on AI trends.
#     * Research papers from reputable academic institutions and conferences (NeurIPS, ICML, etc.).
#     * Company websites and press releases.
#     * News articles from trusted sources (e.g., MIT Technology Review, The Verge, Wired).
#
#
# **Note:**  This content plan requires continuous updating to reflect the dynamic nature of the AI field. The “Noteworthy News” section should be regularly refreshed with the latest developments.  Visuals (images, graphs, charts) should be incorporated throughout the article to enhance engagement.
#
#
# # Agent: Content Writer
# ## Task: 1. Use the content plan to craft a compelling blog post on Artificial Intelligence.
# 2. Incorporate SEO keywords naturally.
# 3. Sections/Subtitles are properly named in an engaging manner.
# 4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing conclusion.
# 5. Proofread for grammatical errors and alignment with the brand's voice.
#
#
#
# # Agent: Content Writer
# ## Final Answer:
# # Understanding the Rise of Artificial Intelligence: A Transformative Technology
#
# **I. Introduction**
#
# Artificial intelligence (AI) is rapidly transforming our world, impacting everything from the way we communicate to how we diagnose diseases.  In 2023 alone, AI-generated content has exploded across the internet, showcasing the technology's remarkable capabilities.  This article will explore the latest trends, key players, and ethical considerations surrounding the rapid advancement of AI, empowering readers to understand and navigate this transformative technology.  We'll delve into the exciting developments in generative AI, its applications in healthcare and sustainability, and the crucial discussions surrounding responsible AI development.
#
# AI, in its broadest sense, refers to the simulation of human intelligence processes by machines, especially computer systems. These processes include learning, reasoning, and self-correction.  The core principles behind AI involve developing algorithms and models that allow computers to analyze data, identify patterns, and make predictions or decisions.  But the field is rapidly evolving, far beyond simple rule-based systems.
#
# This piece aims to demystify AI, separating the hype from the reality and providing a balanced perspective on its potential benefits and risks.
#
#
# **II. Key Trends in Artificial Intelligence**
#
# The AI landscape is dynamic, with several key trends shaping its future.  One of the most significant is the rise of **generative AI**, exemplified by models like GPT-4, DALL-E 2, and Stable Diffusion.  These models can generate human-quality text, images, and even code, opening up exciting possibilities in marketing, design, and software development.  Imagine generating marketing copy in seconds, creating unique artwork effortlessly, or speeding up coding processes. However, this also raises concerns about potential misuse, such as the creation of deepfakes or the spread of misinformation.
#
# Another notable trend is the integration of **AI in healthcare**.  From accelerating drug discovery and enabling personalized medicine to improving diagnostic accuracy and assisting in robotic surgery, AI is revolutionizing patient care and medical research. Companies like IBM Watson Health and Google DeepMind are at the forefront of this revolution, developing AI-powered tools that promise to enhance efficiency and effectiveness.  For instance, AI algorithms can analyze medical images with greater speed and accuracy than human radiologists, potentially leading to earlier diagnoses and better treatment outcomes.
#
# Ethical considerations and regulation are paramount as AI systems become more sophisticated.  Bias in algorithms, data privacy concerns, and the potential for job displacement are all significant challenges.  The EU's AI Act, along with similar initiatives in other countries, underscores the global effort to establish guidelines for responsible AI development. It's crucial to ensure fairness, transparency, and accountability to minimize negative consequences.
#
# Furthermore, **AI for sustainability** is gaining traction.  AI-powered solutions are being employed to address climate change, optimize energy consumption, and enhance resource management.  From AI-powered smart grids that enhance energy efficiency to precision agriculture that reduces waste and environmental impact, the applications are vast and promising. This reflects a shift towards utilizing AI not just for economic gain, but also for positive environmental impact.
#
#
# **III. Key Players Shaping the AI Landscape**
#
# Several tech giants are leading the AI revolution. OpenAI, known for GPT models and its commitment to open-source contributions, is a key player, alongside Google (DeepMind), a leader in deep learning and AI research with applications across diverse fields.  Microsoft, a major investor in OpenAI, is integrating AI into its products, and Amazon (AWS) provides the cloud infrastructure powering much of the AI development. Meta is focusing on AI for social media and augmented reality, while NVIDIA is supplying the powerful GPUs crucial for training AI models.  These companies' investments and innovations are shaping the future trajectory of AI.  Their contributions vary, encompassing fundamental research, software development, and the provision of essential infrastructure.  However, the collaborative and competitive nature of this landscape ensures continuous innovation.
#
# *(Include logos of companies mentioned here)*
#
#
# **IV. Navigating the Future of AI**
#
# The future of AI holds both immense promise and potential risks. We can anticipate further advancements in generative AI, leading to even more sophisticated and creative applications.  AI will likely permeate every aspect of our lives, from personalized education and entertainment to autonomous vehicles and advanced robotics.  However, it is crucial to approach this future with caution and critical thinking.  We must actively address ethical concerns, ensuring that AI is developed and deployed responsibly and inclusively, benefiting humanity as a whole.
#
# The potential impact on the job market is also a critical concern that demands careful consideration and proactive solutions.  It's important to foster a culture of adaptability and innovation that equips individuals with the skills needed to thrive in a world increasingly shaped by AI.  This includes education and training initiatives that focus on emerging fields and on reskilling workers.
#
#
# **V. Conclusion**
#
# Artificial intelligence is undeniably reshaping our world at an unprecedented pace.  Understanding the key trends, players, and ethical considerations is crucial for navigating this transformative technology.  The responsible development and deployment of AI are not just technical challenges but also societal imperatives.  By fostering open dialogue and collaboration, we can harness AI's potential for good while mitigating its potential risks, paving the way for a future where AI serves humanity.
#
#
# **VI. Call to Action**
#
# Share your thoughts on the future of AI in the comments section below.  What are your biggest concerns, and what excites you most about this rapidly evolving technology?  For further learning, explore resources like the MIT Technology Review, the publications of OpenAI, and online courses on AI ethics and development.
#
#
# # Agent: Editor
# ## Task: Proofread the given blog post for grammatical errors and alignment with the brand's voice.
#
#
# # Agent: Editor
# ## Final Answer:
# # Understanding the Rise of Artificial Intelligence: A Transformative Technology
#
# **I. Introduction**
#
# Artificial intelligence (AI) is rapidly transforming our world, impacting nearly every facet of modern life, from communication methods to medical diagnoses.  The proliferation of AI-generated content in 2023 alone vividly illustrates the technology's remarkable capabilities and potential. This article will explore the latest trends, key players, and ethical considerations surrounding AI's rapid advancement, empowering readers to understand and navigate this transformative technology. We'll delve into the exciting developments in generative AI, its applications in healthcare and sustainability, and the crucial discussions surrounding responsible AI development.  The goal is to provide a balanced and informative overview of this rapidly evolving field.
#
# Artificial intelligence, in its broadest definition, involves the creation of computer systems capable of mimicking human cognitive functions.  These functions include learning, reasoning, problem-solving, and self-correction.  Core principles encompass the development of algorithms and models that enable computers to analyze data, identify patterns, and subsequently make predictions or decisions.  However, the field extends far beyond simple rule-based systems, encompassing sophisticated machine learning and deep learning techniques.
#
# This piece aims to demystify AI, separating hype from reality while offering a balanced perspective on its potential benefits and risks, fostering a nuanced understanding for readers.
#
#
# **II. Key Trends in Artificial Intelligence**
#
# The AI landscape is incredibly dynamic, with several key trends shaping its future.  One of the most significant is the rise of generative AI, exemplified by models like GPT-4, DALL-E 2, and Stable Diffusion. These models can generate human-quality text, images, and code, opening exciting possibilities across various sectors, including marketing, design, and software development.  The potential applications are vast, ranging from automatically generating marketing copy to creating unique artwork and accelerating software development cycles.  However, concerns about potential misuse, such as the creation of deepfakes or the spread of misinformation, warrant careful consideration and responsible development practices.
#
# Another prominent trend is the integration of AI in healthcare.  AI is revolutionizing patient care and medical research, accelerating drug discovery, enabling personalized medicine, improving diagnostic accuracy, and assisting in robotic surgery. Companies such as IBM Watson Health and Google DeepMind are at the forefront of this transformation, developing AI-powered tools designed to enhance efficiency and effectiveness within the healthcare system.  For example, AI algorithms can analyze medical images with speed and accuracy exceeding that of human radiologists, potentially leading to earlier diagnoses and improved treatment outcomes.  However, the ethical considerations and data privacy concerns associated with the use of personal health information necessitate careful management and stringent regulatory frameworks.
#
# Ethical considerations and regulation are paramount as AI systems become more sophisticated and prevalent.  Bias in algorithms, data privacy concerns, and the potential for job displacement are significant challenges that require careful attention.  The EU's AI Act, along with similar initiatives globally, highlights the growing international effort to establish guidelines for responsible AI development and deployment.   It is crucial to ensure fairness, transparency, and accountability to minimize negative consequences and maximize the societal benefits of AI.
#
#
# **III. Key Players Shaping the AI Landscape**
#
# Several tech giants are at the forefront of the AI revolution. OpenAI, renowned for its GPT models and commitment to open-source contributions, is a key player. Google (DeepMind), a leader in deep learning and AI research with applications across numerous fields, is another significant contributor. Microsoft, a major investor in OpenAI, is actively integrating AI into its product ecosystem. Amazon (AWS) provides the cloud infrastructure supporting much of the AI development globally. Meta focuses on AI applications within social media and augmented reality. NVIDIA supplies the high-performance GPUs essential for training advanced AI models.  These companies' investments and innovations are shaping the future trajectory of AI.  Their contributions span fundamental research, software development, and the provision of crucial infrastructure. The competitive yet collaborative nature of this landscape fuels ongoing innovation and advancement.
#
# *(Include logos of companies mentioned here)*
#
#
# **IV. Navigating the Future of AI**
#
# The future of AI holds both immense promise and potential risks. We can anticipate further advancements in generative AI, resulting in increasingly sophisticated and creative applications across diverse sectors.  AI's influence will likely permeate nearly every aspect of our lives, from personalized learning experiences and entertainment to autonomous vehicles and advanced robotics.  However, it's crucial to approach this future with caution and a critical mindset.  We must actively address ethical concerns, ensuring that AI is developed and deployed responsibly, inclusively, and equitably, benefiting all of humanity.
#
# The potential impact on the job market is a critical consideration demanding careful planning and proactive solutions.  Fostering adaptability and innovation through education and training initiatives is essential to equip individuals with the skills needed to thrive in a world increasingly shaped by AI.  This includes reskilling and upskilling programs, as well as a focus on emerging fields that will benefit from AI's integration.
#
#
# **V. Conclusion**
#
# Artificial intelligence is undeniably reshaping our world at an unprecedented rate.  Understanding the key trends, prominent players, and ethical considerations is crucial for effectively navigating this transformative technology. Responsible AI development and deployment are not merely technical challenges, but also societal imperatives.  Fostering open dialogue and collaboration allows us to harness AI's potential for good while mitigating its potential risks, paving the way for a future where AI benefits all of humanity.
#
#
# **VI. Call to Action**
#
# Share your perspectives on the future of AI in the comments section below.  What are your greatest concerns, and what aspects of this rapidly evolving technology excite you the most?  To further enhance your understanding, consider exploring resources such as the MIT Technology Review, OpenAI's publications, and reputable online courses focusing on AI ethics and development.
